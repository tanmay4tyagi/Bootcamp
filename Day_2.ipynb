# %%
import numpy as np
players=np.array(['Sachin','Dhoni','Kohli','Raina','Jadeja'])
Matches=np.array(['IPL 2015', 'IPL 2020', 'IPL 2023'])

# 1. Create 5 random numbers
data = np.random.randint(1, 101, size=5)
print("Data:", data)

# 2. Calculate mean and standard deviation along the axis
mean_val = np.mean(data, axis=0)
std_val = np.std(data, axis=0)

# 3. Print results
print("Mean:", mean_val)
print("Standard Deviation:", std_val)
# Out:
# Data: [20 81 89 69  7]
# Mean: 53.2
# Standard Deviation: 33.28903723450109

# %%
import numpy as np
import matplotlib.pyplot as plt

# Create 500 equally spaced time values from 0 to 10
time = np.linspace(0, 10, 500)

# Calculate the amplitude of the sine wave
amplitude = np.sin(2 * np.pi * time)

# Plot the sine wave
plt.plot(time, amplitude)

# Add labels to the graph
plt.xlabel("Time")
plt.ylabel("Amplitude")

# Add title
plt.title("Sine Wave")

# Display the graph
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Generate the engineering data
# 500 points from 0 to 10 seconds
time = np.linspace(0, 10, 500)

# Damped sine wave
amplitude = np.exp(-0.5 * time) * np.sin(2 * np.pi * time)

# 2. Create the Canvas (Figure) and Coordinate Box (Axes) explicitly
fig, ax = plt.subplots(figsize=(8, 4.5), dpi=100)

# 3. Plot the data with customized engineering styles
ax.plot(
    time,
    amplitude,
    color='crimson',
    linewidth=2,
    label='Sensor A Displacement'
)

# 4. Professional Engineering Customizations
ax.set_title(
    'Damped Harmonic Response of Structure',
    fontsize=14,
    fontweight='bold',
    pad=15
)

ax.set_xlabel(
    'Time (seconds)',
    fontsize=12
)

ax.set_ylabel(
    'Displacement (mm)',
    fontsize=12
)

# Enable engineering grid lines
ax.grid(
    True,
    linestyle='--',
    alpha=0.6
)

# Configure the Legend
ax.legend(
    loc='upper right',
    frameon=True,
    shadow=True
)

# 5. Improve layout
plt.tight_layout()

# 6. Display the graph
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
time=np.linspace(0,10,500)
amplitude1= np.sin(np.pi *time)
amplitude2=np.exp(-0.5 * time)* np.sin(2*np.pi*time)
# 2. Create the Canvas (Figure) and Coordinate Box (Axes) explicitly
fig, ax = plt.subplots(figsize=(8, 4.5), dpi=100)
# 3. Plot the data with customized engineering styles
ax.plot(time,amplitude2,color='blue',linewidth=2, label='Sensor A Displacement'
)
ax.plot(time,amplitude1,color='crimson',linewidth=2, label='Sensor A Displacement'
)
ax.set_title('Damped Harmonic Response of Structure', fontsize=14, fontweight='bold', pad=15)
ax.set_xlabel('Time (seconds)', fontsize=12)
ax.set_ylabel('Displacement (mm)', fontsize=12)
# Enable engineering gridlines
ax.grid(True, linestyle='--', alpha=0.6)
# Configure the Legend
ax.legend(loc='upper right', frameon=True, shadow=True)

# %%
import numpy as np

# Generate 2-dimensional random data
data = np.random.randint(1, 101, size=(5, 3))

# Display the data
print("2D Data:")
print(data)

# Save the data into a CSV file
np.savetxt("data.csv", data, delimiter=",", fmt="%d")

print("Data saved successfully in data.csv")
# Out:
# 2D Data:
# [[99  4 62]
#  [72 26 61]
#  [19  1 66]
#  [95 84 17]
#  [43 47 26]]
# Data saved successfully in data.csv

# %%
import pandas as pd
import numpy as np

# Step 2: Generate Random Dataset
data = {
    'Visitor_ID': [f'V{1000 + i}' for i in range(20)],
    'Name': ['ABHISHEK SANDEEP      ZADE     ', 'ARNAV AJAY DESHPANDE.. ', '.. .. ASHWINI LALCHAND MUNDAWARE/ ', 'GAYATRI SURESH GAIKWAD', 'HARSHADA GANESH CHAUDHARI',
             'VAIBHAVI HARISHWAR PATIL', np.nan, 'VISHAKHA PUNDLIK JADHAV', 'YASH BHARAT SOLUNKE/', 'VIVEK SANTOSH KHANDWE',
             'VISHAKHA PUNDLIK JADHAV', 'Tanushree chhanwal', 'Shruti jaiswal', 'Shriyash Sulakhe', 'YASH BHARAT SOLUNKE',
             np.nan, 'ARNAV AJAY DESHPANDE', 'RUTUJA SANTOSH THOTE', 'ROHIT DILIP BILWAL', 'RITESH SHIVAJI BAIRAGI'],
    'Age': [25, 23, 22, np.nan, 21, 25, 24, 24, 28, np.nan,
            22, 23, 25, 27, 25, 30, 31, 26, 19, 19],
    'Ticket_Price': [500, 750, 500, 1000, np.nan, 500, 700, 650, 750, 1000,
                      500, 800, np.nan, 750, 500, 700, 900, 850, 750, np.nan],
    'Check_In_Time': ['10:00 AM', '10:30 AM', '11:00 AM', '11:30 AM', np.nan,
                       '10:00 AM', '12:00 PM', '12:30 PM', '01:00 PM', '01:30 PM',
                       '11:00 AM', '02:00 PM', np.nan, '02:30 PM', '10:00 AM',
                       '12:00 PM', '03:00 PM', '03:30 PM', '04:00 PM', np.nan],
    'City':['Delhi','Aurangabad', 'Mumbai','Bombay','New Delhi','NDL','Chennai','Chenai','Chennaai','Bangalore',
            'Delhi','Pune', 'New Delhi','Bombay','New Delhi','NDL','Indore','Bangalore','Ujjain','Bangalore'],
    'State': ['Delhi','Maharastra', 'Maharastra','Maharastra','Delhi','Delhi','Tamilnadu','Tamilnadu','Tamilnadu','Karnataka',
            'Delhi','Maharastra', 'Delhi','Maharastra','Delhi','Delhi','Madhya Pradesh','Karnataka','Madhya Pradesh','Karnataka']
}
df = pd.DataFrame(data)
df.head()
df = pd.read_csv('khubh_mela_data.csv')
df.to_csv('khubh_mela_data.csv', index=False)
df.head()
# Out:
#   Visitor_ID                                Name   Age  Ticket_Price  \
# 0      V1000     ABHISHEK SANDEEP      ZADE       25.0         500.0
# 1      V1001             ARNAV AJAY DESHPANDE..   23.0         750.0
# 2      V1002  .. .. ASHWINI LALCHAND MUNDAWARE/   22.0         500.0
# 3      V1003              GAYATRI SURESH GAIKWAD   NaN        1000.0
# 4      V1004           HARSHADA GANESH CHAUDHARI  21.0           NaN
#
#   Check_In_Time        City       State
# 0      10:00 AM       Delhi       Delhi
# 1      10:30 AM  Aurangabad  Maharastra
# 2      11:00 AM      Mumbai  Maharastra
# 3      11:30 AM      Bombay  Maharastra
# 4           NaN   New Delhi       Delhi
